# %% [markdown]
# <a href="https://colab.research.google.com/github/modem0011/NLP-Code/blob/main/Regex.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![belajar-regular-expression-e1602544766853.png](data:image/png;base64,...)

# %% [markdown]
# **Regex**
# *   A RegEx, or Regular Expression, is a sequence of characters that forms a search pattern.
# *   RegEx can be used to check if a string contains the specified search pattern.
# *   Python has a built-in package called re, which can be used to work with Regular Expressions.

# %% [markdown]
# **Metacharacters**
#
# *   Metacharacters are characters with a special meaning .

# %% [markdown]
# **[ ]** : A set of characters

# %%
import re
txt = "The rain in Spain"
#Find all lower case characters alphabetically between "a" and "m":
x = re.findall("[a-z]", txt)
print(x)
# Out:
# ['h', 'e', 'r', 'a', 'i', 'n', 'i', 'n', 'p', 'a', 'i', 'n']

# %% [markdown]
# **/** : Signals a special sequence (can also be used to escape special characters)

# %%
import re
txt = "That will be 59 dollars"
#Find all digit characters:
x = re.findall("\d", txt)
print(x)
# Out:
# ['5', '9']

# %% [markdown]
# **.** : Any character (except newline character)

# %%
import re
txt = "hello planet"
#Search for a sequence that starts with "he", followed by two (any) characters, and an "o":
x = re.findall("he..o", txt)
print(x)
# Out:
# ['hello']

# %% [markdown]
# **^** : Starts with

# %%
import re
txt = "Hello planet h"
#Check if the string starts with 'hello':
x = re.findall("^Hello", txt)
print(x)
# Out:
# ['Hello']

# %% [markdown]
# **$** : Ends with

# %%
import re
txt = "hello planet"
#Check if the string ends with 'planet':
x = re.findall("planet$", txt)    # $ symbol should be at the end of that word.
print(x)
# Out:
# ['planet']

# %% [markdown]
# "*" : Zero or more occurrences

# %%
import re
txt = "heo planet"
#Search for a sequence that starts with "he", followed by 0 or more  (any) characters, and an "o":
x = re.findall("he.*o", txt)
print(x)
# Out:
# ['heo']

# %% [markdown]
# **+** : One or more occurrences

# %%
import re
txt = "heoho planet"
#Search for a sequence that starts with "he", followed by 1 or more  (any) characters, and an "o":
x = re.findall("he.+o", txt)
print(x)
# Out:
# ['heoho']

# %% [markdown]
# **?** : Zero or one occurrences

# %%
import re
txt = "heo planet"
#Search for a sequence that starts with "he", followed by 0 or 1  (any) character, and an "o":
x = re.findall("he.?o", txt)
print(x)
#This time we got no match, because there were not zero, not one, but two characters between "he" and the "o"
# Out:
# ['heo']

# %% [markdown]
# **{ }** : Exactly the specified number of occurrences

# %%
import re
txt = "heeo planet"
#Search for a sequence that starts with "he", followed excactly 2 (any) characters, and an "o":
x = re.findall("he{2}o", txt)
print(x)
# Out:
# ['heeo']

# %% [markdown]
# **|** : Either or

# %%
import re
txt = "The rain in Spain falls mainly stays in the plain!"
#Check if the string contains either "falls" or "stays":
x = re.findall("falls|stays", txt)
print(x)
# Out:
# ['falls', 'stays']

# %% [markdown]
# **Special Sequences**
#
#
# *   A special sequence is a \ followed by one of the characters in the list below, and has a special meaning.

# %% [markdown]
# **\A :** Returns a match if the specified characters are at the beginning of the string

# %%
import re
txt = "The rain in Spain"
#Check if the string starts with "The":
x = re.findall("\AThe", txt)
print(x)
# Out:
# ['The']

# %% [markdown]
# **\b** : Returns a match where the specified characters are at the beginning or at the end of a word (the "r" in the beginning is making sure that the string is being treated as a "raw string")

# %%
import re
txt = "The rain in Spain"
#Check if "ain" is present at the beginning of a WORD:
x = re.findall(r"\bain", txt)
print(x)

#Check if "ain" is present at the end of a WORD:
x = re.findall(r"ain\b", txt)
print(x)
# Out:
# []
# ['ain', 'ain']

# %% [markdown]
# **\B** : 	Returns a match where the specified characters are present, but NOT at the beginning (or at the end) of a word
# (the "r" in the beginning is making sure that the string is being treated as a "raw string")

# %%
import re
txt = "The rain in Spain"
#Check if "ain" is present, but NOT at the beginning of a word:
x = re.findall(r"\Bain", txt)
print(x)

x = re.findall(r"ain\B", txt)
print(x)
# Out:
# ['ain', 'ain']
# []

# %% [markdown]
# **\d** : Returns a match where the string contains digits (numbers from 0-9)

# %%
import re
txt = "The rain in Spain 1900"
#Check if the string contains any digits (numbers from 0-9):
x = re.findall("\d", txt)
print(x)
# Out:
# ['1', '9', '0', '0']

# %% [markdown]
# **\D** : Returns a match where the string DOES NOT contain digits

# %%
import re
txt = "The rain in Spain 1900"
#Return a match at every no-digit character:
x = re.findall("\D", txt)
print(x)
# Out:
# ['T', 'h', 'e', ' ', 'r', 'a', 'i', 'n', ' ', 'i', 'n', ' ', 'S', 'p', 'a', 'i', 'n', ' ']

# %% [markdown]
# **\s** : Returns a match where the string contains a white space character

# %%
import re
txt = "The rain in Spain"
#Return a match at every white-space character:
x = re.findall("\s", txt)
print(x)
# Out:
# [' ', ' ', ' ']

# %% [markdown]
# **\S** : 	Returns a match where the string DOES NOT contain a white space character

# %%
import re
txt = "The rain in Spain"
#Return a match at every NON white-space character:
x = re.findall("\S", txt)
print(x)
# Out:
# ['T', 'h', 'e', 'r', 'a', 'i', 'n', 'i', 'n', 'S', 'p', 'a', 'i', 'n']

# %% [markdown]
# **\w** : Returns a match where the string contains any word characters (characters from a to Z, digits from 0-9, and the underscore _ character)

# %%
import re
txt = "The rain in Spain_98 --"
#Return a match at every word character (characters from a to Z, digits from 0-9, and the underscore _ character):
x = re.findall("\w", txt)
print(x)
# Out:
# ['T', 'h', 'e', 'r', 'a', 'i', 'n', 'i', 'n', 'S', 'p', 'a', 'i', 'n', '_', '9', '8']

# %% [markdown]
# **\W** : Returns a match where the string DOES NOT contain any word characters

# %%
import re
txt = "The rain in Spain"
#Return a match at every NON word character (characters NOT between a and Z. Like "!", "?" white-space etc.):
x = re.findall("\W", txt)
print(x)
# Out:
# [' ', ' ', ' ']

# %% [markdown]
# **\Z** : Returns a match if the specified characters are at the end of the string

# %%
import re
txt = "The rain in Spain"
#Check if the string ends with "Spain":
x = re.findall("Spain\Z", txt)
print(x)
# Out:
# ['Spain']

# %% [markdown]
# **Sets**
#
# *   A set is a set of characters inside a pair of square brackets [] with a special meaning:

# %% [markdown]
# **[arn]** : Returns a match where one of the specified characters (a, r, or n) is present

# %%
import re
txt = "The rain in Spain"
#Check if the string has any a, r, or n characters:
x = re.findall("[arn]", txt)
print(x)
# Out:
# ['r', 'a', 'n', 'n', 'a', 'n']

# %% [markdown]
# **[a-n]** : Returns a match for any lower case character, alphabetically between a and n

# %%
import re
txt = "The rain in Spain"
#Check if the string has any characters between a and n:
x = re.findall("[a-n]", txt)
print(x)
# Out:
# ['h', 'e', 'a', 'i', 'n', 'i', 'n', 'a', 'i', 'n']

# %% [markdown]
# **[^arn]** : Returns a match for any character EXCEPT a, r, and n

# %%
import re
txt = "The rain in Spain"
#Check if the string has other characters than a, r, or n:
x = re.findall("[^arn]", txt)
print(x)
# Out:
# ['T', 'h', 'e', ' ', 'i', ' ', 'i', ' ', 'S', 'p', 'i']

# %% [markdown]
# **[0123]** : Returns a match where any of the specified digits (0, 1, 2, or 3) are present

# %%
import re
txt = "The rain in Spain 0392"
#Check if the string has any 0, 1, 2, or 3 digits:
x = re.findall("[01239]", txt)
print(x)
# Out:
# ['0', '3', '9', '2']

# %% [markdown]
# **[0-9]** : Returns a match for any digit between 0 and 9

# %%
import re
txt = "8 times before 11:45 AM"
#Check if the string has any digits:
x = re.findall("[0-9]", txt)
print(x)
# Out:
# ['8', '1', '1', '4', '5']

# %% [markdown]
# **[0-5][0-9]** : Returns a match for any two-digit numbers from 00 and 59

# %%
import re
txt = "8 times before 11:45 AM"
#Check if the string has any two-digit numbers, from 00 to 59:
x = re.findall("[2-5][0-9]", txt)
print(x)
# Out:
# ['45']

# %% [markdown]
# **[a-zA-Z]** :	Returns a match for any character alphabetically between a and z, lower case OR upper case

# %%
import re
txt = "8 times before 11:45 AM"
#Check if the string has any characters from a to z lower case, and A to Z upper case:
x = re.findall("[a-zA-Z]", txt)
print(x)
# Out:
# ['t', 'i', 'm', 'e', 's', 'b', 'e', 'f', 'o', 'r', 'e', 'A', 'M']

# %% [markdown]
# **[+]** : In sets, +, *, ., |, (), $,{} has no special meaning, so [+] means: return a match for any + character in the string

# %%
import re
txt = "8 times before 11:45 AM + "
#Check if the string has any + characters:
x = re.findall("[+]", txt)
print(x)
# Out:
# ['+']

# %% [markdown]
# **RegEx Functions**
#
# *   The re module offers a set of functions that allows us to search a string for a match

# %% [markdown]
# **findall()** : The findall() function returns a list containing all matches.If no matches are found, an empty list is returned.

# %%
import re
#Return a list containing every occurrence of "ai":
txt = "The rain in Spain"
x = re.findall("ai", txt)
print(x)
# Out:
# ['ai', 'ai']

# %% [markdown]
# **search()** : The search() function searches the string for a match, and returns a Match object if there is a match. If there is more than one match, only the first occurrence of the match will be returned

# %%
import re
txt = "The rain in Spain"
x = re.search("\s", txt)
y = re.search("^[z]", txt)
print(x)
print(x.start(),x.end())
print(y)
# Out:
# <re.Match object; span=(3, 4), match=' '>
# 3 4
# None

# %% [markdown]
# **split()** : The split() function returns a list where the string has been split at each match.We can control the number of occurrences by specifying the maxsplit parameter.

# %%
import re
txt = "The rain in Spain"
x = re.split("\s", txt)
y = re.split("i", txt)
z = re.split("i", txt,1)
a = re.split("z", txt)
print(x)
print(y)
print(z)
print(a)
# Out:
# ['The', 'rain', 'in', 'Spain']
# ['The ra', 'n ', 'n Spa', 'n']
# ['The ra', 'n in Spain']
# ['The rain in Spain']

# %% [markdown]
# **sub()** : The sub() function replaces the matches with the text of your choice.We can control the number of replacements by specifying the count parameter.

# %%
import re
txt = "The rain in Spain"
x = re.sub("\s", "9", txt)
y = re.sub("\s", "9", txt ,1)
print(x)
print(y)
# Out:
# The9rain9in9Spain
# The9rain in Spain

# %% [markdown]
# **Match Object**
#
# *   A Match Object is an object containing information about the search and the result.
# *   Note: If there is no match, the value None will be returned, instead of the Match Object.

# %%
import re

#The search() function returns a Match object:

txt = "The rain in Spain"
x = re.search("ai", txt)
print(x)
# Out:
# <re.Match object; span=(5, 7), match='ai'>

# %% [markdown]
# *   **.span()** returns a tuple containing the start-, and end positions of the match.
# *   **.string** returns the string passed into the function
# *   **.group()** returns the part of the string where there was a match

# %%
import re
#Search for an upper case "S" character in the beginning of a word, and print its position:
txt = "The rain in Spain"
x = re.search(r"\bS\w+", txt)
print(x.span())
print(x.string)
print(x.group())
# Out:
# (12, 17)
# The rain in Spain
# Spain
